# %%
import numpy as np
import pandas as pd
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.corpus import wordnet
from nltk import WordNetLemmatizer
from nltk import pos_tag
import nltk

# %%
training_data = pd.read_csv("train.csv")
testing_data = pd.read_csv("test.csv")
x_train = list(training_data['text'])
x_test = list(testing_data['text'])
y_train = list(training_data['airline_sentiment'])

# %%
stops = set(stopwords.words('english'))
punctuations = list(string.punctuation)
stops.update(punctuations)
lemmatizer = WordNetLemmatizer()

# %%
def get_simple_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    if tag.startswith('N'):
        return wordnet.NOUN
    if tag.startswith('V'):
        return wordnet.VERB
    if tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

def clean_doc(doc):
    words = word_tokenize(doc)
    cleaned_words = []
    for word in words:
        if word.lower() not in stops and len(word)>2:
            pos = pos_tag([word])
            clean_word = lemmatizer.lemmatize(word, pos = get_simple_pos(pos[0][1]))
            cleaned_words.append(clean_word)
    return cleaned_words

# %%
train_docs = [clean_doc(doc) for doc in x_train]
test_docs = [clean_doc(doc) for doc in x_test]

# %%
all_words = []
for doc in train_docs:
    for word in doc:
        if(word.lower() not in stops):
            all_words.append(word)

dic = nltk.FreqDist(all_words)
common = dic.most_common(5000)
features = [i[0] for i in common]
features
# Out:
# ['united',
#  'flight',
#  'AmericanAir',
#  'USAirways',
#  'SouthwestAir',
#  'JetBlue',
#  "n't",
#  'get',
#  'http',
#  'hour',
#  'Cancelled',
#  '...',
#  'service',
#  'time',
#  'customer',
#  'help',
#  'call',
#  'bag',
#  'Flight',
#  'wait',
#  'plane',
#  'amp',
#  'hold',
#  'fly',
#  'make',
#  'need',
#  'would',
#  'Thanks',
#  'one',
#  'thanks',
#  'day',
#  'back',
#  'try',
#  'gate',
#  'Flightled',
#  'take',
#  'airline',
#  'say',
#  'still',
#  'VirginAmerica',
#  'delayed',
#  'seat',
#  "'ve",
#  'delay',
#  'change',
#  'like',
#  'Late',
#  'phone',
#  'agent',
#  'bad',
#  'go',
#  'guy',
#  'today',
#  'know',
#  'ticket',
#  'miss',
#  'work',
#  'book',
#  'minute',
#  'please',
#  'give',
#  'United',
#  'airport',
#  'Thank',
#  'way',
#  'could',
#  'min',
#  'lose',
#  'check',
#  "'re",
#  'even',
#  'home',
#  'want',
#  'travel',
#  'tomorrow',
#  'well',
#  'thank',
#  'weather',
#  'see',
#  'use',
#  'last',
#  'people',
#  'email',
#  'issue',
#  'great',
#  'told',
#  "'ll",
#  'sit',
#  'never',
#  'look',
#  'due',
#  'another',
#  'luggage',
#  'really',
#  'number',
#  'good',
#  'trip',
#  'Flighted',
#  'hr',
#  'let',
#  'much',
#  'someone',
#  'baggage',
#  'crew',
#  'first',
#  'passenger',
#  'love',
#  'next',
#  'ever',
#  'reservation',
#  'tell',
#  'two',
#  'response',
#  'experience',
#  'new',
#  'line',
#  'week',
#  'online',
#  'answer',
#  'come',
#  'right',
#  'follow',
#  'sent',
#  'pay',
#  'staff',
#  'connection',
#  'already',
#  'Please',
#  'morning',
#  'leave',
#  'yes',
#  'long',
#  'land',
#  'boarding',
#  'find',
#  'JFK',
#  'problem',
#  'keep',
#  'tonight',
#  'Flightr',
#  'refund',
#  'put',
#  'best',
#  'since',
#  'sure',
#  'think',
#  'board',
#  'update',
#  'mile',
#  'left',
#  'night',
#  'show',
#  'ask',
#  'info',
#  'website',
#  'care',
#  'year',
#  'fleek',
#  'appreciate',
#  'fleet',
#  'Booking',
#  'hotel',
#  'stuck',
#  'Problems',
#  'system',
#  'yet',
#  'talk',
#  'voucher',
#  'attendant',
#  'ago',
#  'rebook',
#  'connect',
#  'anything',
#  'hope',
#  'able',
#  'rebooked',
#  'arrive',
#  'fix',
#  'free',
#  'class',
#  'charge',
#  'DFW',
#  'point',
#  'credit',
#  'thing',
#  'nothing',
#  'pilot',
#  'rep',
#  'checked',
#  'fee',
#  'happen',
#  'option',
#  'add',
#  'via',
#  'start',
#  'upgrade',
#  'rude',
#  'business',
#  'speak',
#  'person',
#  'offer',
#  'frustrate',
#  'fail',
#  'send',
#  'receive',
#  'employee',
#  'team',
#  'flt',
#  'understand',
#  'contact',
#  'tweet',
#  'anyone',
#  'nice',
#  'yesterday',
#  'mean',
#  'name',
#  '1st',
#  'claim',
#  'open',
#  'suck',
#  'status',
#  'helpful',
#  'Help',
#  'suppose',
#  'without',
#  'finally',
#  'always',
#  'earlier',
#  'kid',
#  'friend',
#  'money',
#  'wifi',
#  'usairways',
#  'departure',
#  'extra',
#  'app',
#  'awesome',
#  'every',
#  'something',
#  'though',
#  'return',
#  'air',
#  'schedule',
#  'seem',
#  'available',
#  'instead',
#  'reason',
#  'member',
#  'move',
#  'ground',
#  'hung',
#  'also',
#  'Still',
#  'LAX',
#  'message',
#  'site',
#  'SFO',
#  'many',
#  'full',
#  'pas',
#  'Delta',
#  'disappointed',
#  'early',
#  'respond',
#  'happy',
#  'direct',
#  'least',
#  'snow',
#  'Chicago',
#  'month',
#  'old',
#  'policy',
#  'deal',
#  'family',
#  'chance',
#  'amaze',
#  'plan',
#  'card',
#  'wife',
#  'Need',
#  'PHL',
#  'strand',
#  'company',
#  'DCA',
#  'stop',
#  'food',
#  'cause',
#  'jetblue',
#  'ORD',
#  'almost',
#  'run',
#  'ridiculous',
#  'cost',
#  'allow',
#  'question',
#  'Denver',
#  'paid',
#  'reschedule',
#  'end',
#  'Dallas',
#  'job',
#  'little',
#  'actually',
#  'different',
#  'expect',
#  'terrible',
#  'DestinationDragons',
#  'past',
#  'sorry',
#  'desk',
#  'reply',
#  'link',
#  'EWR',
#  'far',
#  'poor',
#  'enough',
#  'provide',
#  'wrong',
#  'away',
#  'switch',
#  'Southwest',
#  'CLT',
#  'Boston',
#  'account',
#  'Great',
#  'Yes',
#  'treat',
#  'complaint',
#  'lot',
#  'American',
#  'Really',
#  'hang',
#  'row',
#  'San',
#  'request',
#  'horrible',
#  'found',
#  'Vegas',
#  'everyone',
#  'around',
#  'Airways',
#  'car',
#  'soon',
#  'stay',
#  'destination',
#  'feel',
#  'confirm',
#  'handle',
#  'place',
#  'believe',
#  'might',
#  'possible',
#  'bring',
#  'IAD',
#  'runway',
#  'vacation',
#  'else',
#  'confirmation',
#  'load',
#  'computer',
#  'together',
#  'big',
#  'price',
#  'broken',
#  'less',
#  'reach',
#  'process',
#  'hard',
#  'longer',
#  'BOS',
#  'disconnect',
#  'hear',
#  '200',
#  'Twitter',
#  'second',
#  'idea',
#  'Never',
#  'New',
#  'share',
#  'Charlotte',
#  'guess',
#  'twice',
#  'carry',
#  'Thx',
#  'city',
#  'unacceptable',
#  'room',
#  'PHX',
#  'error',
#  'NYC',
#  'mechanical',
#  'thought',
#  'half',
#  'three',
#  'thru',
#  'Newark',
#  'resolve',
#  'sleep',
#  'real',
#  'watch',
#  'drive',
#  'easy',
#  'SWA',
#  'figure',
#  'drop',
#  'lie',
#  'assistance',
#  'flyer',
#  'purchase',
#  'deliver',
#  'apology',
#  'high',
#  'depart',
#  'seriously',
#  'terminal',
#  'mess',
#  'busy',
#  'southwestair',
#  'date',
#  'leg',
#  'lack',
#  'Houston',
#  'forward',
#  'head',
#  'fare',
#  'Monday',
#  'waste',
#  'address',
#  'turn',
#  'counting',
#  'plus',
#  'reFlight',
#  'may',
#  'standby',
#  'word',
#  '1/2',
#  'child',
#  'Customer',
#  'joke',
#  'Trying',
#  'award',
#  'maintenance',
#  'cool',
#  'Good',
#  'close',
#  'thx',
#  'list',
#  'international',
#  '2nd',
#  'Airlines',
#  'Would',
#  'Miami',
#  'quick',
#  'information',
#  'refuse',
#  'group',
#  'traveler',
#  'heard',
#  '800',
#  'explain',
#  'Air',
#  'cust',
#  'worry',
#  'FLL',
#  'situation',
#  'correct',
#  'Love',
#  'detail',
#  'pick',
#  'human',
#  'Another',
#  'First',
#  'spent',
#  'file',
#  'Sunday',
#  'life',
#  'everything',
#  'supervisor',
#  'sat',
#  'IAH',
#  'original',
#  'tarmac',
#  'Worst',
#  'ruin',
#  'Philly',
#  'whole',
#  'entire',
#  'empty',
#  'CEO',
#  'LGA',
#  'screw',
#  'Gate',
#  'report',
#  'part',
#  'route',
#  'Imaginedragons',
#  'maybe',
#  'Flighting',
#  'counter',
#  'sell',
#  'cant',
#  'loyal',
#  'post',
#  'hop',
#  'communication',
#  'hate',
#  'awful',
#  'storm',
#  'fine',
#  'beyond',
#  'sign',
#  '100',
#  'transfer',
#  'Got',
#  'Delayed',
#  'case',
#  'submit',
#  'live',
#  'rather',
#  'force',
#  'form',
#  'Also',
#  'Flightlations',
#  'hey',
#  'record',
#  'flew',
#  'BWI',
#  'fault',
#  'world',
#  'Get',
#  'companion',
#  'flown',
#  'fuck',
#  '1.5',
#  'learn',
#  "y'all",
#  'husband',
#  'HELP',
#  'pretty',
#  'fun',
#  'americanair',
#  'Could',
#  'upset',
#  'drink',
#  '2015',
#  'middle',
#  'door',
#  'support',
#  'Maybe',
#  'UnitedAirlines',
#  'space',
#  'Austin',
#  'several',
#  'medium',
#  'TSA',
#  'kind',
#  'notification',
#  'mom',
#  'southwest',
#  'ready',
#  'Looking',
#  'future',
#  'cover',
#  'dont',
#  'compensation',
#  'page',
#  'water',
#  'Tarmac',
#  'Airport',
#  'Orlando',
#  'rock',
#  'meal',
#  'probably',
#  'Hey',
#  'cross',
#  'item',
#  'attitude',
#  'automate',
#  'Nashville',
#  'lol',
#  'overnight',
#  'Flightlation',
#  'currently',
#  'small',
#  'gon',
#  'matter',
#  'happens',
#  'consider',
#  'clothes',
#  'jet',
#  'note',
#  'overhead',
#  'fact',
#  'knew',
#  'buy',
#  'pass',
#  'notice',
#  'promise',
#  'super',
#  'concern',
#  'safety',
#  'aircraft',
#  'birthday',
#  'either',
#  'story',
#  'arrival',
#  'front',
#  'multiple',
#  'area',
#  'Service',
#  'complete',
#  'top',
#  'save',
#  'jfk',
#  'okay',
#  'course',
#  'wonder',
#  'checkin',
#  'ATL',
#  'USAir',
#  'order',
#  'One',
#  'mine',
#  'luck',
#  'afternoon',
#  'sort',
#  'compensate',
#  'code',
#  'access',
#  'continue',
#  'mobile',
#  'daughter',
#  'cold',
#  'state',
#  'Tuesday',
#  'priority',
#  'failure',
#  'set',
#  'step',
#  'customerservice',
#  'Flt',
#  'country',
#  'track',
#  'PLEASE',
#  'Well',
#  'tire',
#  'enjoy',
#  'yeah',
#  'pls',
#  'layover',
#  'pull',
#  'catch',
#  'acceptable',
#  'Let',
#  'trouble',
#  'WORST',
#  'yall',
#  'Flights',
#  'Unacceptable',
#  'club',
#  'cut',
#  'non',
#  'office',
#  'shit',
#  'crazy',
#  'son',
#  'completely',
#  'despite',
#  'bought',
#  'must',
#  'tag',
#  'ppl',
#  'touch',
#  'begin',
#  'enter',
#  'Nice',
#  '2.5',
#  'Seriously',
#  'explanation',
#  'inconvenience',
#  'ASAP',
#  'RDU',
#  'frequent',
#  'assist',
#  'See',
#  '3rd',
#  'baby',
#  'mind',
#  'Atlanta',
#  'folk',
#  'Friday',
#  'notify',
#  'b/c',
#  'kept',
#  'read',
#  'Finally',
#  'check-in',
#  'Terrible',
#  'usairwaysfail',
#  'include',
#  'wish',
#  'sad',
#  'absolutely',
#  'glad',
#  'lounge',
#  'spend',
#  'DEN',
#  'win',
#  'man',
#  'Feb',
#  'mention',
#  'MCO',
#  'serve',
#  'unable',
#  'merger',
#  'choice',
#  'excite',
#  'deny',
#  'sense',
#  'funeral',
#  'mistake',
#  'window',
#  'extremely',
#  'wonderful',
#  'expire',
#  'announce',
#  'blame',
#  'tix',
#  'Going',
#  'apply',
#  'AmericanAirlines',
#  'itinerary',
#  'blue',
#  'clear',
#  'bother',
#  'excuse',
#  'behind',
#  '2hrs',
#  'WTF',
#  'write',
#  'letter',
#  'round',
#  'honor',
#  'favorite',
#  'damage',
#  'rate',
#  'volume',
#  'Waiting',
#  'cabin',
#  'control',
#  'stand',
#  'BNA',
#  'Hopefully',
#  'Virgin',
#  'apparently',
#  'Flightd',
#  'receipt',
#  'accommodate',
#  'totally',
#  'tmrw',
#  'delta',
#  'video',
#  'twitter',
#  'Philadelphia',
#  'Keep',
#  '1hr',
#  'saw',
#  'anyway',
#  'true',
#  'count',
#  'push',
#  'current',
#  'Sorry',
#  'ice',
#  'entertainment',
#  'select',
#  'airplane',
#  'bumped',
#  'onto',
#  'train',
#  'relation',
#  'locate',
#  'fan',
#  'spoke',
#  'reimburse',
#  'others',
#  'Flying',
#  'Pls',
#  'weekend',
#  'anymore',
#  'mileage',
#  'low',
#  'fill',
#  'hand',
#  'safe',
#  'huge',
#  'dollar',
#  'social',
#  'zero',
#  'exit',
#  'winter',
#  'break',
#  'Phoenix',
#  'platinum',
#  'held',
#  'trust',
#  'Plane',
#  'sick',
#  'captain',
#  'text',
#  'unhappy',
#  'unhelpful',
#  'attempt',
#  'short',
#  'solution',
#  'equipment',
#  'stuff',
#  'program',
#  'tho',
#  'excellent',
#  'Hope',
#  'news',
#  'warm',
#  'sound',
#  'Every',
#  'listen',
#  'nonstop',
#  'dividend',
#  'lady',
#  'welcome',
#  'match',
#  'offering',
#  'center',
#  'wow',
#  'announcement',
#  'LAS',
#  'special',
#  'representative',
#  'Tried',
#  'advisory',
#  'Next',
#  'Seattle',
#  'coffee',
#  'airway',
#  'walk',
#  'final',
#  'emergency',
#  'resolution',
#  'March',
#  'clearly',
#  'Saturday',
#  'remember',
#  'photo',
#  'four',
#  'takeoff',
#  'redeem',
#  'damn',
#  'Missed',
#  'department',
#  'apologize',
#  'w/o',
#  'Last',
#  'nightmare',
#  'accept',
#  'carrier',
#  'Stuck',
#  'bus',
#  'Glad',
#  'ride',
#  'bank',
#  'suggest',
#  'raise',
#  'bin',
#  'Makes',
#  'slow',
#  'regard',
#  'haha',
#  'snack',
#  'kill',
#  'msg',
#  'svc',
#  'Club',
#  'impressed',
#  'callback',
#  'choose',
#  'likely',
#  'surprise',
#  'avgeek',
#  'complain',
#  'Even',
#  'assign',
#  'onboard',
#  'Come',
#  'visit',
#  'professional',
#  'broke',
#  'require',
#  'worth',
#  'effort',
#  'merge',
#  'Diego',
#  'inflight',
#  'deplane',
#  'willing',
#  'inside',
#  'prefer',
#  'play',
#  'Best',
#  'gotten',
#  'May',
#  'woman',
#  'feedback',
#  'die',
#  'per',
#  'realize',
#  'web',
#  'rule',
#  'discount',
#  'security',
#  'bit',
#  'game',
#  'difference',
#  'hire',
#  'PDX',
#  'Wall',
#  'upgraded',
#  'badservice',
#  'actual',
#  'training',
#  'auto',
#  'dfwairport',
#  'single',
#  'earn',
#  'Made',
#  'Bad',
#  'catering',
#  'useless',
#  'alert',
#  'outside',
#  'prompt',
#  'except',
#  'fair',
#  'party',
#  'view',
#  'Big',
#  'freeze',
#  'dca',
#  'unfortunately',
#  'waive',
#  'Looks',
#  'red',
#  'Agent',
#  'PHLAirport',
#  'definitely',
#  'become',
#  'NEVER',
#  'face',
#  'advise',
#  'suggestion',
#  'Awesome',
#  'commercial',
#  'lax',
#  'LUV',
#  'absolute',
#  'neveragain',
#  'major',
#  'fast',
#  'Mexico',
#  'traffic',
#  'condition',
#  'domestic',
#  'disgust',
#  'hell',
#  'power',
#  'meeting',
#  'ahead',
#  'Jet',
#  'experienced',
#  'fit',
#  'impossible',
#  'level',
#  'expensive',
#  'Flightling',
#  'delivery',
#  'eat',
#  'taxi',
#  'iPhone',
#  'personal',
#  'client',
#  'reserve',
#  'appear',
#  'Everyone',
#  'THANK',
#  'forgot',
#  'infant',
#  'wont',
#  'Appreciate',
#  'avoid',
#  'character',
#  'stewardess',
#  ...]

# %%
def create_dict(doc):
    freq = nltk.FreqDist(doc)
    curr_features = {}
    for word in features:
        if word in freq:
            curr_features[word] = freq[word]
        else:
            curr_features[word] = 0
    return curr_features

# %%
training = [(create_dict(train_docs[i]),y_train[i]) for i in range(len(train_docs))]

# %%
testing = [create_dict(test_docs[i]) for i in range(len(test_docs))]

# %%
from nltk import NaiveBayesClassifier
clf = NaiveBayesClassifier.train(training)

# %%
y_pred = clf.classify_many(testing)
print(y_pred)
# Out:
# ['negative', 'negative', 'negative', 'neutral', 'positive', 'negative', 'negative', 'negative', 'negative', 'negative', 'negative', 'negative', 'neutral', 'negative', 'negative', 'negative', 'positive', 'neutral', 'negative', 'negative', 'positive', 'neutral', 'negative', 'negative', 'negative', 'neutral', 'positive', 'negative', 'neutral', 'negative', 'neutral', 'positive', 'negative', 'negative', 'negative', 'negative', 'negative', 'negative', 'negative', 'negative', 'positive', 'negative', 'negative', 'positive', 'negative', 'negative', 'negative', 'negative', 'neutral', 'negative', 'neutral', 'negative', 'negative', 'positive', 'negative', 'negative', 'negative', 'negative', 'positive', 'negative', 'negative', 'negative', 'negative', 'negative', 'positive', 'positive', 'positive', 'negative', 'neutral', 'negative', 'negative', 'negative', 'neutral', 'negative', 'negative', 'negative', 'negative', 'negative', 'negative', 'neutral', 'negative', 'negative', 'negative', 'negative', 'negative', 'neutral', 'negative', 'neutral', 'negative', 'positive', 'negative', 'neutral', 'negative', 'negative', 'positive', 'neutral', 'neutral', 'positive', 'neutral', 'negative', 'negative', 'positive', 'negative', 'negative', 'negative', 'positive', 'negative', 'negative', 'negative', 'negative', 'negative', 'negative', 'neutral', 'negative', 'negative', 'neutral', 'negative', 'negative', 'neutral', 'negative', 'negative', 'negative', 'negative', 'neutral', 'neutral', 'positive', 'negative', 'negative', 'negative', 'neutral', 'neutral', 'negative', 'negative', 'negative', 'positive', 'negative', 'negative', 'negative', 'positive', 'positive', 'positive', 'negative', 'negative', 'neutral', 'neutral', 'negative', 'negative', 'neutral', 'negative', 'neutral', 'positive', 'neutral', 'negative', 'positive', 'neutral', 'negative', 'negative', 'neutral', 'negative', 'negative', 'negative', 'neutral', 'neutral', 'negative', 'neutral', 'positive', 'negative', 'negative', 'neutral', 'negative', 'positive', 'negative', 'positive', 'negative', 'negative', 'neutral', 'negative', 'negative', 'negative', 'negative', 'positive', 'negative', 'negative', 'neutral', 'negative', 'neutral', 'neutral', 'neutral', 'negative', 'negative', 'negative', 'negative', 'neutral', 'negative', 'neutral', 'negative', 'negative', 'negative', 'positive', 'neutral', 'negative', 'neutral', 'negative', 'negative', 'negative', 'neutral', 'negative', 'positive', 'negative', 'negative', 'neutral', 'negative', 'negative', 'negative', 'negative', 'negative', 'negative', 'negative', 'negative', 'negative', 'positive', 'positive', 'negative', 'positive', 'negative', 'negative', 'neutral', 'neutral', 'positive', 'negative', 'neutral', 'negative', 'negative', 'positive', 'negative', 'negative', 'negative', 'negative', 'neutral', 'positive', 'negative', 'neutral', 'negative', 'neutral', 'negative', 'neutral', 'neutral', 'negative', 'positive', 'negative', 'negative', 'negative', 'positive', 'negative', 'negative', 'negative', 'negative', 'negative', 'positive', 'negative', 'negative', 'negative', 'negative', 'positive', 'negative', 'negative', 'positive', 'neutral', 'negative', 'positive', 'negative', 'neutral', 'positive', 'negative', 'negative', 'negative', 'positive', 'positive', 'negative', 'neutral', 'negative', 'negative', 'negative', 'negative', 'negative', 'negative', 'neutral', 'negative', 'neutral', 'negative', 'neutral', 'negative', 'neutral', 'negative', 'negative', 'negative', 'positive', 'neutral', 'negative', 'negative', 'neutral', 'positive', 'negative', 'neutral', 'positive', 'negative', 'negative', 'negative', 'positive', 'negative', 'negative', 'neutral', 'neutral', 'neutral', 'negative', 'negative', 'negative', 'neutral', 'neutral', 'negative', 'positive', 'neutral', 'negative', 'negative', 'negative', 'negative', 'negative', 'negative', 'negative', 'negative', 'neutral', 'negative', 'negative', 'negative', 'negative', 'negative', 'negative', 'positive', 'negative', 'ne ...

# %%
pd.DataFrame(y_pred).to_csv("submission file.csv")
