# %%
from nltk.corpus import movie_reviews
documents=[]
for category in movie_reviews.categories():
    for fileid in movie_reviews.fileids(category):
        documents.append((movie_reviews.words(fileid), category))

# %%
import random
random.shuffle(documents)

# %%
from nltk.corpus import wordnet
from nltk import pos_tag
from nltk.corpus import stopwords
import string
from nltk.stem import WordNetLemmatizer
lemmatizer=WordNetLemmatizer()
stops=set(stopwords.words('english'))
punctuations=list(string.punctuation)
stops.update(punctuations)
def get_simple_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    if tag.startswith('N'):
        return wordnet.NOUN
    if tag.startswith('V'):
        return wordnet.VERB
    if tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN
def clean_review(words):
    clean_words=[]
    for word in words:
        if word.lower() not in stops:
            pos=pos_tag([word])[0][1]
            clean_word=lemmatizer.lemmatize(word, pos=get_simple_pos(pos))
            clean_words.append(clean_word.lower())
    return clean_words

# %%
docs=[(clean_review(document), category) for document, category in documents]

# %%
all_words=[]
for tup in docs:
    all_words+=tup[0]

# %%
import nltk
freq=nltk.FreqDist(all_words)
common=freq.most_common(3000)
features=[i[0] for i in common]
features
# Out:
# ['film',
#  'movie',
#  'one',
#  'make',
#  'like',
#  'character',
#  'get',
#  'see',
#  'go',
#  'time',
#  'well',
#  'scene',
#  'even',
#  'good',
#  'story',
#  'take',
#  'would',
#  'much',
#  'come',
#  'also',
#  'bad',
#  'give',
#  'life',
#  'two',
#  'look',
#  'way',
#  'know',
#  'seem',
#  'first',
#  'end',
#  '--',
#  'year',
#  'work',
#  'thing',
#  'plot',
#  'say',
#  'play',
#  'really',
#  'little',
#  'show',
#  'people',
#  'could',
#  'man',
#  'star',
#  'love',
#  'never',
#  'try',
#  'great',
#  'director',
#  'best',
#  'performance',
#  'new',
#  'big',
#  'many',
#  'action',
#  'actor',
#  'want',
#  'u',
#  'watch',
#  'find',
#  'think',
#  'role',
#  'act',
#  'another',
#  'back',
#  'audience',
#  'something',
#  'world',
#  'turn',
#  'still',
#  'day',
#  'old',
#  'set',
#  'however',
#  'use',
#  'every',
#  'begin',
#  'though',
#  'guy',
#  'part',
#  'comedy',
#  'feel',
#  'cast',
#  'real',
#  'enough',
#  'around',
#  'point',
#  'interest',
#  'last',
#  'run',
#  'write',
#  'young',
#  'may',
#  'fact',
#  'name',
#  'long',
#  'funny',
#  'script',
#  'actually',
#  'right',
#  'woman',
#  'minute',
#  'effect',
#  'almost',
#  'lot',
#  'friend',
#  'nothing',
#  'john',
#  'place',
#  'although',
#  'screen',
#  'played',
#  'ever',
#  'start',
#  'moment',
#  'since',
#  'line',
#  'call',
#  'become',
#  'tell',
#  'lead',
#  'kill',
#  'original',
#  'help',
#  'high',
#  'family',
#  'without',
#  'three',
#  'problem',
#  'picture',
#  'girl',
#  'least',
#  'quite',
#  'sequence',
#  'need',
#  'away',
#  'course',
#  'laugh',
#  'might',
#  'far',
#  'fall',
#  'rather',
#  'must',
#  'anything',
#  'put',
#  'include',
#  'bit',
#  'child',
#  'job',
#  'american',
#  'yet',
#  'follow',
#  'keep',
#  'wife',
#  'alien',
#  'kind',
#  'hour',
#  'hard',
#  'always',
#  'reason',
#  'fun',
#  'head',
#  'feature',
#  'special',
#  'attempt',
#  'hand',
#  'home',
#  'human',
#  'hollywood',
#  'instead',
#  'lose',
#  'sense',
#  'move',
#  'war',
#  'mind',
#  'series',
#  'face',
#  'night',
#  'black',
#  'half',
#  'let',
#  'probably',
#  'shot',
#  'kid',
#  'along',
#  'men',
#  'idea',
#  'everything',
#  'pretty',
#  'becomes',
#  'direct',
#  'dialogue',
#  'sure',
#  'together',
#  'force',
#  'money',
#  'involve',
#  'believe',
#  'talk',
#  'father',
#  'save',
#  'whole',
#  'fight',
#  'horror',
#  'death',
#  'appear',
#  'boy',
#  'everyone',
#  'city',
#  'question',
#  'sex',
#  'music',
#  'do',
#  'less',
#  'release',
#  'second',
#  'couple',
#  'thought',
#  'brother',
#  'eye',
#  'perhaps',
#  'small',
#  'case',
#  'next',
#  'especially',
#  'expect',
#  'happen',
#  'meet',
#  '10',
#  'relationship',
#  'mother',
#  'word',
#  'base',
#  'create',
#  'completely',
#  'care',
#  '2',
#  'rest',
#  'whose',
#  'evil',
#  'writer',
#  'change',
#  'different',
#  'james',
#  'sound',
#  'simply',
#  'mean',
#  'mr',
#  'book',
#  'anyone',
#  'school',
#  'joke',
#  'late',
#  'michael',
#  'review',
#  'top',
#  'several',
#  'dead',
#  'humor',
#  'live',
#  'suppose',
#  'lack',
#  'left',
#  'add',
#  'true',
#  'town',
#  'matter',
#  'entire',
#  'hit',
#  'group',
#  'found',
#  'fan',
#  'comic',
#  'soon',
#  'house',
#  'someone',
#  'main',
#  'entertain',
#  'tv',
#  'game',
#  'leave',
#  'side',
#  'wrong',
#  'present',
#  'wonder',
#  'david',
#  'else',
#  'either',
#  'element',
#  'full',
#  'final',
#  'later',
#  'stop',
#  'unfortunately',
#  'viewer',
#  'murder',
#  'car',
#  'open',
#  'style',
#  'enjoy',
#  'camera',
#  'return',
#  'support',
#  'credit',
#  'robert',
#  'often',
#  'provide',
#  'power',
#  'die',
#  'deal',
#  'son',
#  'hero',
#  'behind',
#  'certainly',
#  'person',
#  'title',
#  'result',
#  'team',
#  'despite',
#  'scream',
#  'perfect',
#  'finally',
#  'video',
#  'order',
#  'nice',
#  'killer',
#  'stand',
#  'note',
#  'maybe',
#  'miss',
#  'piece',
#  'summer',
#  'past',
#  'able',
#  'fine',
#  'view',
#  'consider',
#  'classic',
#  'example',
#  'strong',
#  'voice',
#  'daughter',
#  'hope',
#  'theater',
#  'situation',
#  'production',
#  'sort',
#  'thriller',
#  'close',
#  'event',
#  'white',
#  'dog',
#  'kevin',
#  'talent',
#  'joe',
#  'drama',
#  'break',
#  'body',
#  'worth',
#  'earth',
#  'heart',
#  'short',
#  'bring',
#  'cut',
#  'version',
#  'level',
#  'self',
#  'dark',
#  'dream',
#  'room',
#  'early',
#  'cop',
#  'nearly',
#  'opening',
#  'upon',
#  'ask',
#  'screenplay',
#  'light',
#  'experience',
#  'age',
#  'violence',
#  'major',
#  'art',
#  'throughout',
#  'figure',
#  'ship',
#  'direction',
#  'beautiful',
#  'jack',
#  'computer',
#  'exactly',
#  'realize',
#  'obvious',
#  'state',
#  'genre',
#  'disney',
#  'already',
#  'plan',
#  'number',
#  'others',
#  'fill',
#  'wait',
#  'guess',
#  'waste',
#  'space',
#  'deep',
#  'five',
#  'offer',
#  'simple',
#  'form',
#  'four',
#  'jackie',
#  'king',
#  'learn',
#  'surprise',
#  'twist',
#  'touch',
#  'walk',
#  'pull',
#  'chase',
#  'career',
#  'flick',
#  'rise',
#  'sometimes',
#  'oscar',
#  'novel',
#  'hold',
#  'member',
#  'truly',
#  'battle',
#  'filmmaker',
#  '1',
#  'boring',
#  'husband',
#  'tom',
#  'easy',
#  'pace',
#  'drug',
#  'god',
#  'lee',
#  'peter',
#  'type',
#  'york',
#  'sequel',
#  'planet',
#  'charm',
#  'fiction',
#  'win',
#  'carry',
#  'parent',
#  'happens',
#  'yes',
#  'song',
#  'saw',
#  'tale',
#  'remember',
#  'stupid',
#  'quickly',
#  'score',
#  'romantic',
#  'possible',
#  'gun',
#  'chance',
#  'villain',
#  'manages',
#  'material',
#  'extremely',
#  'mostly',
#  'attention',
#  'de',
#  'future',
#  'project',
#  'single',
#  'particularly',
#  'escape',
#  'focus',
#  'quality',
#  'paul',
#  'none',
#  'police',
#  'mention',
#  'co',
#  'stay',
#  'decide',
#  'eventually',
#  'hell',
#  'crime',
#  'van',
#  'wild',
#  'emotional',
#  'image',
#  'science',
#  'sit',
#  'shoot',
#  'large',
#  'smith',
#  'dr',
#  'girlfriend',
#  'pay',
#  'living',
#  'steal',
#  'detail',
#  'rock',
#  'drive',
#  'low',
#  'success',
#  'actress',
#  'george',
#  'theme',
#  'alone',
#  'television',
#  'obviously',
#  'cover',
#  'usually',
#  'within',
#  'million',
#  'water',
#  'among',
#  'premise',
#  'cause',
#  'middle',
#  'read',
#  '3',
#  'complete',
#  'secret',
#  'aspect',
#  'subject',
#  'across',
#  'understand',
#  'flaw',
#  'except',
#  'chris',
#  'mission',
#  'poor',
#  'history',
#  'slow',
#  'whether',
#  'local',
#  'wonderful',
#  'reality',
#  'oh',
#  'amaze',
#  'agent',
#  'law',
#  'serious',
#  'crew',
#  'effort',
#  'motion',
#  'happy',
#  'important',
#  'mark',
#  'impressive',
#  'studio',
#  'explain',
#  'near',
#  'america',
#  'office',
#  'stuff',
#  'told',
#  'entertainment',
#  'cool',
#  'recent',
#  'street',
#  'robin',
#  'basically',
#  'produce',
#  'ryan',
#  'easily',
#  'apparently',
#  'message',
#  'wish',
#  'attack',
#  'williams',
#  'screenwriter',
#  'mystery',
#  'vampire',
#  'party',
#  'somehow',
#  'william',
#  'lie',
#  'blood',
#  'fear',
#  'bill',
#  'fast',
#  'fire',
#  'control',
#  'doubt',
#  'jones',
#  'batman',
#  'brings',
#  'suspense',
#  'straight',
#  'producer',
#  'red',
#  'difficult',
#  'hilarious',
#  'country',
#  'appeal',
#  'ben',
#  'certain',
#  'romance',
#  'ago',
#  'approach',
#  'due',
#  'popular',
#  'business',
#  'presence',
#  'company',
#  'effective',
#  'critic',
#  'annoy',
#  'confuse',
#  'answer',
#  'throw',
#  'adult',
#  'fly',
#  'teen',
#  'trouble',
#  'fail',
#  'smart',
#  'general',
#  'third',
#  'dramatic',
#  'budget',
#  'class',
#  'date',
#  'speak',
#  'sexual',
#  'discover',
#  'rich',
#  'clear',
#  'us',
#  'surprisingly',
#  'anyway',
#  '4',
#  'personal',
#  'emotion',
#  'decides',
#  'share',
#  'cross',
#  'somewhat',
#  'ability',
#  'choice',
#  'harry',
#  'rat',
#  'sister',
#  'former',
#  'similar',
#  'previous',
#  'excite',
#  'absolutely',
#  'successful',
#  'prison',
#  'cinema',
#  'jim',
#  'allow',
#  'strange',
#  'student',
#  'intelligent',
#  'leaf',
#  'excellent',
#  'familiar',
#  'rule',
#  'dance',
#  'giant',
#  'powerful',
#  'predictable',
#  'bob',
#  'towards',
#  'box',
#  'b',
#  'animate',
#  'visual',
#  'shock',
#  'beyond',
#  'victim',
#  'nature',
#  'trailer',
#  'la',
#  'r',
#  'sam',
#  'tone',
#  'deliver',
#  'usual',
#  'catch',
#  'martin',
#  'clever',
#  'blue',
#  'definitely',
#  'master',
#  'murphy',
#  'brilliant',
#  'felt',
#  'stone',
#  'wedding',
#  'suspect',
#  'scary',
#  'manage',
#  'reveal',
#  'bunch',
#  'musical',
#  'solid',
#  'appearance',
#  'capture',
#  'pick',
#  'mess',
#  'favorite',
#  'rating',
#  'land',
#  'reach',
#  'handle',
#  'travel',
#  'treat',
#  'potential',
#  'grow',
#  'seriously',
#  'free',
#  'wear',
#  'track',
#  'hunt',
#  'huge',
#  'search',
#  'continue',
#  'amount',
#  'week',
#  'unlike',
#  'married',
#  'sweet',
#  'l',
#  'perfectly',
#  'join',
#  'non',
#  'issue',
#  'ex',
#  'hate',
#  'park',
#  'scott',
#  'enjoyable',
#  'e',
#  'decent',
#  'strike',
#  'bond',
#  'likely',
#  'adventure',
#  'truman',
#  'private',
#  'depth',
#  'frank',
#  'heard',
#  'immediately',
#  'ten',
#  'cameron',
#  'door',
#  'bruce',
#  'monster',
#  'richard',
#  'fails',
#  'cold',
#  'inside',
#  'race',
#  'overall',
#  'impossible',
#  'carter',
#  'toy',
#  'truth',
#  'step',
#  'purpose',
#  'merely',
#  'particular',
#  'trek',
#  'neither',
#  'color',
#  'sight',
#  'sign',
#  'prove',
#  'gag',
#  'air',
#  'struggle',
#  'mar',
#  'ultimately',
#  'design',
#  'drop',
#  'list',
#  'brought',
#  'pop',
#  'spirit',
#  'personality',
#  'modern',
#  'thrill',
#  'club',
#  'term',
#  'allen',
#  'otherwise',
#  'cliche',
#  'wood',
#  'tim',
#  'society',
#  '5',
#  'player',
#  'key',
#  'dumb',
#  'fashion',
#  'government',
#  'serve',
#  'various',
#  'opportunity',
#  'amuse',
#  'west',
#  'talented',
#  'political',
#  'succeed',
#  'angel',
#  'soundtrack',
#  'army',
#  'development',
#  'sell',
#  'mouth',
#  'haunt',
#  'silly',
#  'raise',
#  'female',
#  'english',
#  'introduce',
#  'month',
#  'slightly',
#  'train',
#  'hank',
#  'detective',
#  'steve',
#  'require',
#  'imagine',
#  'roll',
#  'spend',
#  'tension',
#  'lover',
#  'kiss',
#  'compare',
#  'grace',
#  'eddie',
#  'foot',
#  'disaster',
#  'creature',
#  'baby',
#  'earlier',
#  'today',
#  'chan',
#  '90',
#  'award',
#  'cannot',
#  'memorable',
#  'six',
#  'heavy',
#  'hill',
#  'max',
#  'rescue',
#  'ground',
#  'episode',
#  'totally',
#  'background',
#  'front',
#  'notice',
#  'respect',
#  'leader',
#  'ape',
#  'fi',
#  'soldier',
#  'woody',
#  'animation',
#  'engage',
#  'hop',
#  'machine',
#  'edit',
#  'arm',
#  'sci',
#  'mary',
#  'doctor',
#  'terrible',
#  'ride',
#  'costume',
#  'simon',
#  'actual',
#  'constantly',
#  'steven',
#  'impact',
#  'british',
#  'entirely',
#  'standard',
#  'queen',
#  'fantasy',
#  'suffer',
#  'minor',
#  'promise',
#  'convincing',
#  'ridiculous',
#  'atmosphere',
#  'animal',
#  'officer',
#  'quick',
#  'brief',
#  '8',
#  'rush',
#  'spent',
#  'menace',
#  'typical',
#  'island',
#  'nick',
#  'cinematography',
#  'road',
#  'building',
#  'bug',
#  'violent',
#  'grant',
#  'partner',
#  'double',
#  'trip',
#  'subtle',
#  'adam',
#  'cameo',
#  'inspire',
#  'dollar',
#  'fairly',
#  'seven',
#  'beauty',
#  'concept',
#  'cheap',
#  'dress',
#  'suddenly',
#  'willis',
#  'store',
#  'whatever',
#  'remain',
#  'college',
#  'bore',
#  'president',
#  'highly',
#  'complex',
#  'dull',
#  'ii',
#  'indeed',
#  'basic',
#  'suit',
#  'pair',
#  'mike',
#  'recommend',
#  'flat',
#  'recently',
#  'titanic',
#  'kick',
#  'frame',
#  'cute',
#  'plenty',
#  'godzilla',
#  'brain',
#  'outside',
#  'cinematic',
#  'meanwhile',
#  'climax',
#  'awful',
#  'hear',
#  'x',
#  'intrigue',
#  'clearly',
#  'prof',
#  'forget',
#  'buddy',
#  'tough',
#  'longer',
#  'century',
#  'realistic',
#  'chemistry',
#  'believable',
#  'common',
#  'admit',
#  'scientist',
#  'conclusion',
#  'sean',
#  'protagonist',
#  'lawyer',
#  'period',
#  'band',
#  'encounter',
#  'language',
#  'possibly',
#  'male',
#  'sing',
#  'twenty',
#  'aside',
#  'hang',
#  'brown',
#  'camp',
#  'french',
#  'carrey',
#  'thin',
#  'center',
#  'hot',
#  'somewhere',
#  'witch',
#  'jerry',
#  'system',
#  'slowly',
#  ...]

# %%
training_documents=docs[0:1500]
testing_documents=docs[1500:]

# %%
def get_feature_dict(words):
    current_features={}
    words_set=set(words)
    for w in features:
        current_features[w]=w in words_set
    return current_features

# %%
training_data=[(get_feature_dict(doc), category)for doc, category in training_documents]

# %%
testing_data=[(get_feature_dict(doc), category)for doc, category in testing_documents]

# %%
from nltk import NaiveBayesClassifier
clf=NaiveBayesClassifier.train(training_data)

# %%
nltk.classify.accuracy(clf, testing_data)
# Out:
# 0.774

# %%
clf.show_most_informative_features(500)
# Out:
# Most Informative Features
#              outstanding = True              pos : neg    =     14.0 : 1.0
#                   sinise = True              neg : pos    =      9.4 : 1.0
#                   seagal = True              neg : pos    =      9.4 : 1.0
#                    jolie = True              neg : pos    =      8.7 : 1.0
#                stupidity = True              neg : pos    =      8.7 : 1.0
#                 lifeless = True              neg : pos    =      7.9 : 1.0
#                ludicrous = True              neg : pos    =      7.1 : 1.0
#                   turkey = True              neg : pos    =      6.8 : 1.0
#                      sat = True              neg : pos    =      6.8 : 1.0
#                    idiot = True              neg : pos    =      6.5 : 1.0
#                    jesus = True              pos : neg    =      6.4 : 1.0
#                     jedi = True              pos : neg    =      6.4 : 1.0
#                    damon = True              pos : neg    =      6.3 : 1.0
#             breathtaking = True              pos : neg    =      6.3 : 1.0
#               uninspired = True              neg : pos    =      6.2 : 1.0
#                  freddie = True              neg : pos    =      6.0 : 1.0
#                    poker = True              pos : neg    =      6.0 : 1.0
#                   anakin = True              pos : neg    =      5.9 : 1.0
#              wonderfully = True              pos : neg    =      5.9 : 1.0
#                 religion = True              pos : neg    =      5.8 : 1.0
#                 contrast = True              pos : neg    =      5.7 : 1.0
#                   random = True              neg : pos    =      5.7 : 1.0
#                     lame = True              neg : pos    =      5.7 : 1.0
#                  refresh = True              pos : neg    =      5.5 : 1.0
#                    anger = True              pos : neg    =      5.4 : 1.0
#                   prinze = True              neg : pos    =      5.2 : 1.0
#               schumacher = True              neg : pos    =      5.2 : 1.0
#                  idiotic = True              neg : pos    =      4.8 : 1.0
#                   alicia = True              neg : pos    =      4.8 : 1.0
#                    waste = True              neg : pos    =      4.8 : 1.0
#                painfully = True              neg : pos    =      4.7 : 1.0
#                   poorly = True              neg : pos    =      4.6 : 1.0
#                 flawless = True              pos : neg    =      4.6 : 1.0
#                      era = True              pos : neg    =      4.6 : 1.0
#                  balance = True              pos : neg    =      4.6 : 1.0
#              beautifully = True              pos : neg    =      4.5 : 1.0
#                   mature = True              pos : neg    =      4.5 : 1.0
#                  tedious = True              neg : pos    =      4.5 : 1.0
#               ridiculous = True              neg : pos    =      4.5 : 1.0
#                    notch = True              pos : neg    =      4.5 : 1.0
#                  unfunny = True              neg : pos    =      4.5 : 1.0
#                memorable = True              pos : neg    =      4.4 : 1.0
#                pointless = True              neg : pos    =      4.3 : 1.0
#                  fincher = True              pos : neg    =      4.3 : 1.0
#                  garbage = True              neg : pos    =      4.3 : 1.0
#                    awful = True              neg : pos    =      4.3 : 1.0
#                 scorsese = True              pos : neg    =      4.3 : 1.0
#            uninteresting = True              neg : pos    =      4.2 : 1.0
#                   allows = True              pos : neg    =      4.2 : 1.0
#                 terrible = True              neg : pos    =      4.2 : 1.0
#             respectively = True              pos : neg    =      4.2 : 1.0
#                 ordinary = True              pos : neg    =      4.2 : 1.0
#                  triumph = True              pos : neg    =      4.2 : 1.0
#                    ideal = True              pos : neg    =      4.2 : 1.0
#                   belief = True              pos : neg    =      4.2 : 1.0
#                    inept = True              neg : pos    =      4.2 : 1.0
#               whatsoever = True              neg : pos    =      4.1 : 1.0
#                 terrific = True              pos : neg    =      4.0 : 1.0
#                embarrass = True              neg : pos    =      4.0 : 1.0
#                      obi = True              pos : neg    =      4.0 : 1.0
#               delightful = True              pos : neg    =      3.9 : 1.0
#                    shine = True              pos : neg    =      3.9 : 1.0
#                     dull = True              neg : pos    =      3.8 : 1.0
#                 lebowski = True              pos : neg    =      3.8 : 1.0
#                   subtle = True              pos : neg    =      3.8 : 1.0
#                   insult = True              neg : pos    =      3.8 : 1.0
#                  comfort = True              pos : neg    =      3.7 : 1.0
#                   stupid = True              neg : pos    =      3.7 : 1.0
#                 mcgregor = True              pos : neg    =      3.7 : 1.0
#                    snipe = True              neg : pos    =      3.7 : 1.0
#                   superb = True              pos : neg    =      3.7 : 1.0
#                    snake = True              neg : pos    =      3.7 : 1.0
#              brilliantly = True              pos : neg    =      3.6 : 1.0
#                    bland = True              neg : pos    =      3.6 : 1.0
#                      gem = True              pos : neg    =      3.6 : 1.0
#                   german = True              pos : neg    =      3.6 : 1.0
#                    slick = True              pos : neg    =      3.6 : 1.0
#                       54 = True              neg : pos    =      3.6 : 1.0
#                   endear = True              pos : neg    =      3.5 : 1.0
#                    crowe = True              pos : neg    =      3.5 : 1.0
#              fortunately = True              pos : neg    =      3.5 : 1.0
#                     yell = True              neg : pos    =      3.5 : 1.0
#             contemporary = True              pos : neg    =      3.5 : 1.0
#               nomination = True              pos : neg    =      3.5 : 1.0
#                laughable = True              neg : pos    =      3.4 : 1.0
#                fantastic = True              pos : neg    =      3.4 : 1.0
#                innocence = True              pos : neg    =      3.4 : 1.0
#                    upper = True              pos : neg    =      3.4 : 1.0
#                   norton = True              pos : neg    =      3.3 : 1.0
#                   dillon = True              pos : neg    =      3.3 : 1.0
#                     diaz = True              pos : neg    =      3.3 : 1.0
#                  stiller = True              pos : neg    =      3.3 : 1.0
#                   welles = True              neg : pos    =      3.3 : 1.0
#                   martha = True              neg : pos    =      3.3 : 1.0
#                   sidney = True              pos : neg    =      3.3 : 1.0
#                     mill = True              pos : neg    =      3.3 : 1.0
#                   boring = True              neg : pos    =      3.3 : 1.0
#                     slip = True              pos : neg    =      3.3 : 1.0
#               philosophy = True              pos : neg    =      3.3 : 1.0
#                perfectly = True              pos : neg    =      3.2 : 1.0
#               friendship = True              pos : neg    =      3.2 : 1.0
#                      ace = True              neg : pos    =      3.2 : 1.0
#                 terribly = True              neg : pos    =      3.2 : 1.0
#                portrayal = True              pos : neg    =      3.2 : 1.0
#                    inane = True              neg : pos    =      3.2 : 1.0
#                 anywhere = True              neg : pos    =      3.1 : 1.0
#                   bottle = True              neg : pos    =      3.1 : 1.0
#                   harris = True              pos : neg    =      3.1 : 1.0
#                    darth = True              pos : neg    =      3.1 : 1.0
#                     grip = True              pos : neg    =      3.1 : 1.0
#                  unusual = True              pos : neg    =      3.1 : 1.0
#                  october = True              pos : neg    =      3.1 : 1.0
#                 politics = True              pos : neg    =      3.1 : 1.0
#                      neo = True              pos : neg    =      3.1 : 1.0
#                   castle = True              pos : neg    =      3.1 : 1.0
#                  freedom = True              pos : neg    =      3.1 : 1.0
#                  collect = True              pos : neg    =      3.1 : 1.0
#                   tucker = True              pos : neg    =      3.1 : 1.0
#                portrayed = True              pos : neg    =      3.1 : 1.0
#                  destine = True              pos : neg    =      3.1 : 1.0
#                    fargo = True              pos : neg    =      3.1 : 1.0
#                  chuckle = True              neg : pos    =      3.1 : 1.0
#                    plant = True              neg : pos    =      3.1 : 1.0
#                        0 = True              neg : pos    =      3.1 : 1.0
#                    randy = True              neg : pos    =      3.1 : 1.0
#                  frankly = True              neg : pos    =      3.0 : 1.0
#                 develops = True              pos : neg    =      3.0 : 1.0
#              consequence = True              pos : neg    =      3.0 : 1.0
#                realistic = True              pos : neg    =      3.0 : 1.0
#                hilarious = True              pos : neg    =      2.9 : 1.0
#                      sir = True              pos : neg    =      2.9 : 1.0
#                    clich = True              neg : pos    =      2.9 : 1.0
#                 nonsense = True              neg : pos    =      2.9 : 1.0
#                   besson = True              neg : pos    =      2.9 : 1.0
#                  connery = True              neg : pos    =      2.9 : 1.0
#                      luc = True              neg : pos    =      2.9 : 1.0
#                   jackal = True              neg : pos    =      2.9 : 1.0
#           schwarzenegger = True              neg : pos    =      2.9 : 1.0
#                      eve = True              neg : pos    =      2.9 : 1.0
#                   lethal = True              neg : pos    =      2.9 : 1.0
#                excellent = True              pos : neg    =      2.9 : 1.0
#                initially = True              pos : neg    =      2.9 : 1.0
#                 identify = True              pos : neg    =      2.9 : 1.0
#                    karen = True              pos : neg    =      2.9 : 1.0
#                     anna = True              pos : neg    =      2.9 : 1.0
#                   spacey = True              pos : neg    =      2.9 : 1.0
#                    equal = True              pos : neg    =      2.8 : 1.0
#                   period = True              pos : neg    =      2.8 : 1.0
#                     mess = True              neg : pos    =      2.8 : 1.0
#              traditional = True              pos : neg    =      2.8 : 1.0
#                 prisoner = True              pos : neg    =      2.8 : 1.0
#                sacrifice = True              pos : neg    =      2.8 : 1.0
#                     zero = True              neg : pos    =      2.8 : 1.0
#                    badly = True              neg : pos    =      2.8 : 1.0
#                  failure = True              neg : pos    =      2.8 : 1.0
#                     snow = True              pos : neg    =      2.8 : 1.0
#                     niro = True              pos : neg    =      2.8 : 1.0
#              shakespeare = True              pos : neg    =      2.8 : 1.0
#                    lucas = True              pos : neg    =      2.8 : 1.0
#                wonderful = True              pos : neg    =      2.8 : 1.0
#                  citizen = True              pos : neg    =      2.8 : 1.0
#                   lonely = True              pos : neg    =      2.8 : 1.0
#                     tony = True              pos : neg    =      2.8 : 1.0
#                    quiet = True              pos : neg    =      2.8 : 1.0
#                effective = True              pos : neg    =      2.7 : 1.0
#                 likeable = True              pos : neg    =      2.7 : 1.0
#                   remake = True              neg : pos    =      2.7 : 1.0
#                brilliant = True              pos : neg    =      2.7 : 1.0
#                     liam = True              pos : neg    =      2.7 : 1.0
#                   empire = True              pos : neg    =      2.7 : 1.0
#                    naked = True              neg : pos    =      2.7 : 1.0
#                      joy = True              pos : neg    =      2.7 : 1.0
#                  acclaim = True              pos : neg    =      2.7 : 1.0
#                     pile = True              neg : pos    =      2.7 : 1.0
#                    julie = True              neg : pos    =      2.7 : 1.0
#                 remotely = True              neg : pos    =      2.7 : 1.0
#                  gabriel = True              neg : pos    =      2.7 : 1.0
#                     zeta = True              neg : pos    =      2.7 : 1.0
#                 showgirl = True              neg : pos    =      2.7 : 1.0
#                  trilogy = True              pos : neg    =      2.7 : 1.0
#                 portrait = True              pos : neg    =      2.7 : 1.0
#                   ripley = True              pos : neg    =      2.7 : 1.0
#                 detailed = True              pos : neg    =      2.7 : 1.0
#                    felix = True              pos : neg    =      2.7 : 1.0
#                     mood = True              pos : neg    =      2.7 : 1.0
#                    blair = True              neg : pos    =      2.7 : 1.0
#                  luckily = True              pos : neg    =      2.7 : 1.0
#             conventional = True              pos : neg    =      2.7 : 1.0
#                fascinate = True              pos : neg    =      2.7 : 1.0
#                   redeem = True              neg : pos    =      2.7 : 1.0
#                promising = True              neg : pos    =      2.7 : 1.0
#                   affect = True              pos : neg    =      2.6 : 1.0
#                   tragic = True              pos : neg    =      2.6 : 1.0
#                    alice = True              pos : neg    =      2.6 : 1.0
#                  emperor = True              pos : neg    =      2.6 : 1.0
#                      jar = True              pos : neg    =      2.6 : 1.0
#                     pitt = True              pos : neg    =      2.6 : 1.0
#                    solid = True              pos : neg    =      2.6 : 1.0
#                    craft = True              pos : neg    =      2.6 : 1.0
#                     suck = True              neg : pos    =      2.6 : 1.0
#                    palma = True              neg : pos    =      2.6 : 1.0
#                 midnight = True              pos : neg    =      2.6 : 1.0
#                    eager = True              pos : neg    =      2.6 : 1.0
#                     reef = True              neg : pos    =      2.6 : 1.0
#                      ape = True              neg : pos    =      2.6 : 1.0
#                     rick = True              neg : pos    =      2.6 : 1.0
#                    hokey = True              neg : pos    =      2.6 : 1.0
#                    color = True              pos : neg    =      2.6 : 1.0
#                  italian = True              pos : neg    =      2.6 : 1.0
#               historical = True              pos : neg    =      2.6 : 1.0
#                      own = True              pos : neg    =      2.6 : 1.0
#                    judge = True              pos : neg    =      2.6 : 1.0
#                  delight = True              pos : neg    =      2.6 : 1.0
#                     warm = True              pos : neg    =      2.6 : 1.0
#                    witty = True              pos : neg    =      2.6 : 1.0
#                      rip = True              neg : pos    =      2.6 : 1.0
#                      ala = True              neg : pos    =      2.6 : 1.0
#                  cameron = True              pos : neg    =      2.6 : 1.0
#            extraordinary = True              pos : neg    =      2.6 : 1.0
#            appropriately = True              pos : neg    =      2.6 : 1.0
#                   deeply = True              pos : neg    =      2.6 : 1.0
#                   depict = True              pos : neg    =      2.6 : 1.0
#                  kubrick = True              pos : neg    =      2.5 : 1.0
#                 visually = True              pos : neg    =      2.5 : 1.0
#                    faith = True              pos : neg    =      2.5 : 1.0
#                    antic = True              neg : pos    =      2.5 : 1.0
#                 designer = True              pos : neg    =      2.5 : 1.0
#                   altman = True              pos : neg    =      2.5 : 1.0
#                   bother = True              neg : pos    =      2.5 : 1.0
#                     noir = True              pos : neg    =      2.5 : 1.0
#                    oscar = True              pos : neg    =      2.5 : 1.0
#                    blame = True              neg : pos    =      2.5 : 1.0
#                     cave = True              neg : pos    =      2.5 : 1.0
#                wrestling = True              neg : pos    =      2.5 : 1.0
#                    disco = True              neg : pos    =      2.5 : 1.0
#               remarkable = True              pos : neg    =      2.5 : 1.0
#              potentially = True              neg : pos    =      2.4 : 1.0
#                  variety = True              pos : neg    =      2.4 : 1.0
#                   cheesy = True              neg : pos    =      2.4 : 1.0
#                spielberg = True              pos : neg    =      2.4 : 1.0
#             nevertheless = True              pos : neg    =      2.4 : 1.0
#                     crap = True              neg : pos    =      2.4 : 1.0
#                    shall = True              pos : neg    =      2.4 : 1.0
#                    derek = True              pos : neg    =      2.4 : 1.0
#                    carol = True              pos : neg    =      2.4 : 1.0
#                    irish = True              pos : neg    =      2.4 : 1.0
#                     bite = True              neg : pos    =      2.4 : 1.0
#                   mildly = True              neg : pos    =      2.4 : 1.0
#              masterpiece = True              pos : neg    =      2.4 : 1.0
#                concerned = True              pos : neg    =      2.4 : 1.0
#                   regard = True              pos : neg    =      2.4 : 1.0
#                 ensemble = True              pos : neg    =      2.4 : 1.0
#                   status = True              pos : neg    =      2.4 : 1.0
#                   method = True              pos : neg    =      2.4 : 1.0
#                  reflect = True              pos : neg    =      2.4 : 1.0
#                    fails = True              neg : pos    =      2.4 : 1.0
#                   mortal = True              neg : pos    =      2.4 : 1.0
#                   highly = True              pos : neg    =      2.4 : 1.0
#                    dread = True              pos : neg    =      2.4 : 1.0
#                  nervous = True              pos : neg    =      2.4 : 1.0
#                 sinister = True              pos : neg    =      2.4 : 1.0
#                     jake = True              pos : neg    =      2.4 : 1.0
#                      pat = True              pos : neg    =      2.4 : 1.0
#                  society = True              pos : neg    =      2.4 : 1.0
#                     rare = True              pos : neg    =      2.4 : 1.0
#                  intense = True              pos : neg    =      2.4 : 1.0
#                   social = True              pos : neg    =      2.4 : 1.0
#                    tense = True              pos : neg    =      2.4 : 1.0
#                    squad = True              neg : pos    =      2.4 : 1.0
#                     data = True              neg : pos    =      2.4 : 1.0
#                    tribe = True              neg : pos    =      2.4 : 1.0
#                      pig = True              pos : neg    =      2.3 : 1.0
#                   paxton = True              pos : neg    =      2.3 : 1.0
#                     iron = True              pos : neg    =      2.3 : 1.0
#                  nowhere = True              neg : pos    =      2.3 : 1.0
#                  natural = True              pos : neg    =      2.3 : 1.0
#                     rent = True              neg : pos    =      2.3 : 1.0
#                 strength = True              pos : neg    =      2.3 : 1.0
#                   taylor = True              neg : pos    =      2.3 : 1.0
#                  tragedy = True              pos : neg    =      2.3 : 1.0
#                     flaw = True              pos : neg    =      2.3 : 1.0
#               perfection = True              pos : neg    =      2.3 : 1.0
#                     wire = True              neg : pos    =      2.3 : 1.0
#                    damme = True              neg : pos    =      2.3 : 1.0
#                    keanu = True              neg : pos    =      2.3 : 1.0
#                   galaxy = True              pos : neg    =      2.3 : 1.0
#                  perfect = True              pos : neg    =      2.3 : 1.0
#                    sharp = True              pos : neg    =      2.3 : 1.0
#                   dennis = True              neg : pos    =      2.3 : 1.0
#                    devil = True              neg : pos    =      2.3 : 1.0
#                  heroine = True              pos : neg    =      2.3 : 1.0
#                narration = True              pos : neg    =      2.3 : 1.0
#                    fully = True              pos : neg    =      2.3 : 1.0
#                     dumb = True              neg : pos    =      2.3 : 1.0
#                  robocop = True              pos : neg    =      2.3 : 1.0
#                     antz = True              pos : neg    =      2.3 : 1.0
#                  portray = True              pos : neg    =      2.3 : 1.0
#                 powerful = True              pos : neg    =      2.3 : 1.0
#                 harrison = True              pos : neg    =      2.3 : 1.0
#                      sin = True              pos : neg    =      2.3 : 1.0
#                      wan = True              pos : neg    =      2.3 : 1.0
#                  teacher = True              pos : neg    =      2.3 : 1.0
#                    sorry = True              neg : pos    =      2.3 : 1.0
#                   jungle = True              neg : pos    =      2.3 : 1.0
#               sutherland = True              neg : pos    =      2.3 : 1.0
#                      kim = True              neg : pos    =      2.3 : 1.0
#                     judd = True              neg : pos    =      2.3 : 1.0
#                   amanda = True              neg : pos    =      2.3 : 1.0
#               henstridge = True              neg : pos    =      2.3 : 1.0
#              krippendorf = True              neg : pos    =      2.3 : 1.0
#                  sandler = True              neg : pos    =      2.3 : 1.0
#                  overall = True              pos : neg    =      2.3 : 1.0
#                  command = True              pos : neg    =      2.3 : 1.0
#                  journey = True              pos : neg    =      2.3 : 1.0
#                     sens = True              pos : neg    =      2.2 : 1.0
#                   convey = True              pos : neg    =      2.2 : 1.0
#              sentimental = True              pos : neg    =      2.2 : 1.0
#                ambitious = True              pos : neg    =      2.2 : 1.0
#                 deserves = True              pos : neg    =      2.2 : 1.0
#                political = True              pos : neg    =      2.2 : 1.0
#                  generic = True              neg : pos    =      2.2 : 1.0
#                  contact = True              pos : neg    =      2.2 : 1.0
#                 involves = True              neg : pos    =      2.2 : 1.0
#                   resort = True              pos : neg    =      2.2 : 1.0
#                criticism = True              pos : neg    =      2.2 : 1.0
#               thankfully = True              pos : neg    =      2.2 : 1.0
#               stereotype = True              neg : pos    =      2.2 : 1.0
#                  beloved = True              pos : neg    =      2.2 : 1.0
#                 creation = True              pos : neg    =      2.2 : 1.0
#                 parallel = True              pos : neg    =      2.2 : 1.0
#                    upset = True              pos : neg    =      2.2 : 1.0
#                  succeed = True              pos : neg    =      2.2 : 1.0
#                  vehicle = True              neg : pos    =      2.2 : 1.0
#                    clone = True              neg : pos    =      2.2 : 1.0
#                   slowly = True              pos : neg    =      2.2 : 1.0
#               revelation = True              pos : neg    =      2.2 : 1.0
#                    drunk = True              neg : pos    =      2.2 : 1.0
#                   guilty = True              neg : pos    =      2.2 : 1.0
#                   gloria = True              pos : neg    =      2.2 : 1.0
#                 dicaprio = True              pos : neg    =      2.2 : 1.0
#                    sport = True              neg : pos    =      2.2 : 1.0
#                       17 = True              pos : neg    =      2.2 : 1.0
#                  slasher = True              neg : pos    =      2.2 : 1.0
#                     twin = True              neg : pos    =      2.2 : 1.0
#                   unique = True              pos : neg    =      2.2 : 1.0
#                malkovich = True              pos : neg    =      2.2 : 1.0
#                    reese = True              pos : neg    =      2.2 : 1.0
#                      pam = True              pos : neg    =      2.2 : 1.0
#                  product = True              neg : pos    =      2.2 : 1.0
#                animation = True              pos : neg    =      2.2 : 1.0
#               compelling = True              pos : neg    =      2.2 : 1.0
#                    court = True              pos : neg    =      2.2 : 1.0
#                 pathetic = True              neg : pos    =      2.1 : 1.0
#                     anti = True              pos : neg    =      2.1 : 1.0
#                 canadian = True              pos : neg    =      2.1 : 1.0
#                  quentin = True              pos : neg    =      2.1 : 1.0
#                   neeson = True              pos : neg    =      2.1 : 1.0
#                 mitchell = True              pos : neg    =      2.1 : 1.0
#              predictable = True              neg : pos    =      2.1 : 1.0
#                  pattern = True              pos : neg    =      2.1 : 1.0
#                  colonel = True              pos : neg    =      2.1 : 1.0
#                  suppose = True              neg : pos    =      2.1 : 1.0
#                   beauty = True              pos : neg    =      2.1 : 1.0
#                      8mm = True              neg : pos    =      2.1 : 1.0
#                     gere = True              neg : pos    =      2.1 : 1.0
#                  warrior = True              neg : pos    =      2.1 : 1.0
#                    stalk = True              neg : pos    =      2.1 : 1.0
#                    comet = True              neg : pos    =      2.1 : 1.0
#                    slide = True              pos : neg    =      2.1 : 1.0
#              independent = True              pos : neg    =      2.1 : 1.0
#                     bore = True              neg : pos    =      2.1 : 1.0
#                      sub = True              neg : pos    =      2.1 : 1.0
#               supposedly = True              neg : pos    =      2.1 : 1.0
#              inspiration = True              pos : neg    =      2.1 : 1.0
#                 portrays = True              pos : neg    =      2.1 : 1.0
#                     stir = True              pos : neg    =      2.1 : 1.0
#                    boast = True              pos : neg    =      2.1 : 1.0
#                    loyal = True              pos : neg    =      2.1 : 1.0
#                   assign = True              pos : neg    =      2.1 : 1.0
#                   spirit = True              pos : neg    =      2.1 : 1.0
#                   knight = True              pos : neg    =      2.1 : 1.0
#                  complex = True              pos : neg    =      2.1 : 1.0
#                     pack = True              pos : neg    =      2.1 : 1.0
#                     tour = True              pos : neg    =      2.1 : 1.0
#                     deny = True              pos : neg    =      2.1 : 1.0
#                    coach = True              neg : pos    =      2.1 : 1.0
#                 football = True              neg : pos    =      2.1 : 1.0
#                     porn = True              neg : pos    =      2.1 : 1.0
#                   hollow = True              neg : pos    =      2.1 : 1.0
#                 colorful = True              pos : neg    =      2.1 : 1.0
#             storytelling = True              pos : neg    =      2.1 : 1.0
#              achievement = True              pos : neg    =      2.1 : 1.0
#                   oliver = True              pos : neg    =      2.1 : 1.0
#              predecessor = True              pos : neg    =      2.1 : 1.0
#                       as = True              neg : pos    =      2.1 : 1.0
#                     doom = True              pos : neg    =      2.1 : 1.0
#                  passion = True              pos : neg    =      2.1 : 1.0
#                childhood = True              pos : neg    =      2.1 : 1.0
#                naturally = True              pos : neg    =      2.1 : 1.0
#                     pulp = True              pos : neg    =      2.1 : 1.0
#                     matt = True              pos : neg    =      2.1 : 1.0
#                   winner = True              pos : neg    =      2.1 : 1.0
#              emotionally = True              pos : neg    =      2.1 : 1.0
#                structure = True              pos : neg    =      2.1 : 1.0
#                     epic = True              pos : neg    =      2.1 : 1.0
#                therefore = True              pos : neg    =      2.1 : 1.0
#                    craze = True              neg : pos    =      2.1 : 1.0
#                    chick = True              neg : pos    =      2.1 : 1.0
#                 somebody = True              neg : pos    =      2.1 : 1.0
#                   normal = True              pos : neg    =      2.1 : 1.0
#                   refuse = True              pos : neg    =      2.1 : 1.0
#                   worker = True              pos : neg    =      2.1 : 1.0
#                     stun = True              pos : neg    =      2.1 : 1.0
#                chemistry = True              pos : neg    =      2.1 : 1.0
#                  reality = True              pos : neg    =      2.1 : 1.0
#                    share = True              pos : neg    =      2.1 : 1.0
#                     page = True              neg : pos    =      2.1 : 1.0
#                     skip = True              neg : pos    =      2.1 : 1.0
#                    touch = True              pos : neg    =      2.1 : 1.0
#                   excuse = True              neg : pos    =      2.1 : 1.0
#                 saturday = True              neg : pos    =      2.1 : 1.0
#                    cheap = True              neg : pos    =      2.1 : 1.0
#              intelligent = True              pos : neg    =      2.1 : 1.0
#                     none = True              neg : pos    =      2.0 : 1.0
#                     cage = True              neg : pos    =      2.0 : 1.0
#                   medium = True              pos : neg    =      2.0 : 1.0
#                    grand = True              pos : neg    =      2.0 : 1.0
#                   others = True              pos : neg    =      2.0 : 1.0
#                  satisfy = True              pos : neg    =      2.0 : 1.0
#                 irritate = True              neg : pos    =      2.0 : 1.0
#                   honest = True              pos : neg    =      2.0 : 1.0
#              spectacular = True              pos : neg    =      2.0 : 1.0
#                       ed = True              pos : neg    =      2.0 : 1.0
#                  justice = True              pos : neg    =      2.0 : 1.0
#                   reward = True              pos : neg    =      2.0 : 1.0
#                tradition = True              pos : neg    =      2.0 : 1.0
#                    maybe = True              neg : pos    =      2.0 : 1.0
#              nonetheless = True              pos : neg    =      2.0 : 1.0
#              explanation = True              neg : pos    =      2.0 : 1.0
#                affection = True              pos : neg    =      2.0 : 1.0
#                 pleasant = True              pos : neg    =      2.0 : 1.0
#                    motif = True              pos : neg    =      2.0 : 1.0
#                    north = True              pos : neg    =      2.0 : 1.0
#                 secretly = True              pos : neg    =      2.0 : 1.0
#                     mass = True              pos : neg    =      2.0 : 1.0
#                      gag = True              neg : pos    =      2.0 : 1.0
#                universal = True              pos : neg    =      2.0 : 1.0
#                    eerie = True              pos : neg    =      2.0 : 1.0
#                broderick = True              neg : pos    =      2.0 : 1.0
#                  directs = True              pos : neg    =      2.0 : 1.0
#               phenomenon = True              pos : neg    =      2.0 : 1.0
#                    lloyd = True              pos : neg    =      2.0 : 1.0
#                 astonish = True              pos : neg    =      2.0 : 1.0
#                companion = True              pos : neg    =      2.0 : 1.0
#                     alec = True              pos : neg    =      2.0 : 1.0
#                    civil = True              pos : neg    =      2.0 : 1.0
#               importance = True              pos : neg    =      2.0 : 1.0
#                  subplot = True              neg : pos    =      2.0 : 1.0
#                    clerk = True              neg : pos    =      2.0 : 1.0
#                  crystal = True              neg : pos    =      2.0 : 1.0
#                   mickey = True              neg : pos    =      2.0 : 1.0
#                   warren = True              neg : pos    =      2.0 : 1.0
#                  america = True              pos : neg    =      2.0 : 1.0
#                    fairy = True              pos : neg    =      2.0 : 1.0
#                  fiennes = True              pos : neg    =      2.0 : 1.0
#                    fifth = True              neg : pos    =      2.0 : 1.0
#                 godzilla = True              neg : pos    =      2.0 : 1.0
#                  massive = True              neg : pos    =      2.0 : 1.0
#                     born = True              pos : neg    =      2.0 : 1.0
#                   insert = True              neg : pos    =      2.0 : 1.0
#                    fonda = True              pos : neg    =      2.0 : 1.0
#                   famous = True              pos : neg    =      2.0 : 1.0
#                   angela = True              pos : neg    =      2.0 : 1.0
#                 richards = True              pos : neg    =      2.0 : 1.0
#                     pure = True              pos : neg    =      2.0 : 1.0
#                  trailer = True              neg : pos    =      2.0 : 1.0
#                     flat = True              neg : pos    =      2.0 : 1.0
#                        b = True              neg : pos    =      2.0 : 1.0
#                    grade = True              neg : pos    =      2.0 : 1.0
#                    bunch = True              neg : pos    =      2.0 : 1.0
#                   strong = True              pos : neg    =      2.0 : 1.0
#                     lord = True              pos : neg    =      2.0 : 1.0
#                  halfway = True              neg : pos    =      2.0 : 1.0
#                      war = True              pos : neg    =      2.0 : 1.0
#                 personal = True              pos : neg    =      2.0 : 1.0
#                  capsule = True              neg : pos    =      2.0 : 1.0
#               unexpected = True              pos : neg    =      2.0 : 1.0
#                      con = True              neg : pos    =      2.0 : 1.0
#                  painful = True              neg : pos    =      2.0 : 1.0
#                  pretend = True              neg : pos    =      2.0 : 1.0
#                      woo = True              neg : pos    =      2.0 : 1.0
#                     gary = True              neg : pos    =      2.0 : 1.0
#                    harry = True              neg : pos    =      2.0 : 1.0
#                   nicely = True              pos : neg    =      2.0 : 1.0
#                    moral = True              pos : neg    =      2.0 : 1.0
#                 neighbor = True              pos : neg    =      2.0 : 1.0
#                    frank = True              pos : neg    =      2.0 : 1.0
#                     rich = True              pos : neg    =      2.0 : 1.0
#                    honor = True              pos : neg    =      2.0 : 1.0
#              combination = True              pos : neg    =      2.0 : 1.0

# %%
clf.classify_many([tup[0] for tup in testing_data])
# Out:
# ['pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg']
